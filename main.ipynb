# %%
import os
os.getcwd()
# Out:
# '/Users/mananshah7/Desktop/Data Analysis Tools'

# %%
# !pip install yahoo_fin

# %%
# !pip install yahooquery

# %%
import pandas as pd 
import yfinance as yf 
import yahooquery

# %%
from yahoo_fin.stock_info import get_data
import yahoo_fin.stock_info as si
from yahooquery import Ticker

# %%
#examine stock IPOs and ETF IPOs over the period 2012-2020.  extracted all stocks with first trading day after January 1, 2012. 
#start date 1/1/2012 end date 1/1/2021

# %%
stock_ipos= pd.read_csv('stocks_ipos.csv')

# %%
snp_list=pd.read_csv('snp500_list.csv')

# %%
Rusell_factors=pd.read_csv('russell_Factors_20210124.csv')

# %%
ETF_ipos = pd.read_csv('etfs_ipos.csv')

# %%
#Compare the performance of an average overall IPOs’ return compared to investing in the Russell-3000 ETF(IWV) over all return horizons in the above variables. 
#Please address both average return and risk.

# %%
#sym_day0_OTC' measures the return from open to close in the IPO
#Variables that start with iwv measure corresponding return on the Russell-3000 ETFs

# %%
stock_ipos
# Out:
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2326        2326  POWRU      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# 2329        2329   DFHT      Financial Services
# 2330        2330    CAS      Financial Services
#
#                                     industry    ipo_date  sym_day0_OTC  \
# 0                         Auto Manufacturers  2018-09-12      0.100000
# 1     Drug ManufacturersÑSpecialty & Generic  2014-07-15     -0.082443
# 2                           Telecom Services  2019-04-18     -0.046154
# 3     Drug ManufacturersÑSpecialty & Generic  2019-08-01     -0.348694
# ...

# %%
variables=  ['symbol','sector','industry','ipo_date',
'sym_day0_OTC','sym_1day_ret','sym_5day_ret','sym_22day_ret','sym_91day_ret', 'sym_252day_ret'
'iwv_day0_OTC','iwv_1day_ret', 'iwv_5day_ret','iwv_22day_ret','iwv_91day_ret','iwv_252day_ret']

# %%
len(variables)
# Out:
# 15

# %%
#Changing name to stock_IPO_list
stock_IPO_list = pd.DataFrame(stock_ipos)

# %%
# # Filtering the ipo date to be before January 2021, as project requires between 2012-2020
# #have to work on this 
stock_IPO_list=stock_ipos
stock_IPO_list = stock_IPO_list.loc[stock_IPO_list['ipo_date'] < '2021-01-01-'] 
stock_IPO_list
# Out:
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# 2329        2329   DFHT      Financial Services
#
#                                     industry    ipo_date  sym_day0_OTC  \
# 0                         Auto Manufacturers  2018-09-12      0.100000
# 1     Drug ManufacturersÑSpecialty & Generic  2014-07-15     -0.082443
# 2                           Telecom Services  2019-04-18     -0.046154
# 3     Drug ManufacturersÑSpecialty & Generic  2019-08-01     -0.348694
# ...

# %%
#Variables that start with iwv measure corresponding return on the Russell-3000 ETFs
#SYM meansures returns fron stock dates

# %%
stock_IPO_list[['sym_day0_OTC','sym_1day_ret','sym_5day_ret','sym_22day_ret','sym_91day_ret', 'sym_252day_ret',
'iwv_day0_OTC','iwv_1day_ret', 'iwv_5day_ret','iwv_22day_ret','iwv_91day_ret','iwv_252day_ret']] .describe ()
# Out:
#        sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  sym_91day_ret  \
# count   2265.000000   2265.000000   2265.000000    2265.000000    2265.000000
# mean       0.864428      0.041280      0.053452       0.100227       0.216778
# std       40.322031      1.130455      1.326109       1.651445       2.850084
# min       -0.569231     -0.980934     -0.999047      -0.900000      -0.955556
# 25%       -0.027273     -0.016667     -0.026667      -0.057143      -0.142289
# 50%        0.000000      0.000000      0.000000       0.007032       0.014754
# 75%        0.025277      0.020161      0.038650       0.094450       0.212457
# max     1919.000119     53.000000     61.381819      57.981814      89.200000
#
#        sym_252day_ret  iwv_day0_OTC  iwv_1day_ret  iwv_5day_ret  \
# count     2265.000000   2265.000000   2265.000000   2265.000000
# mean         0.256358     -0.000014      0.000674      0.204274
# std          3.527711      0.007545      0.009363      0.407428
# ...

# %%
stock_IPO_list_final=stock_IPO_list[['sym_day0_OTC','sym_1day_ret','sym_5day_ret','sym_22day_ret','sym_91day_ret', 'sym_252day_ret',
'iwv_day0_OTC','iwv_1day_ret', 'iwv_5day_ret','iwv_22day_ret','iwv_91day_ret','iwv_252day_ret']] .describe ()
stock_IPO_list_final
# Out:
#        sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  sym_91day_ret  \
# count   2265.000000   2265.000000   2265.000000    2265.000000    2265.000000
# mean       0.864428      0.041280      0.053452       0.100227       0.216778
# std       40.322031      1.130455      1.326109       1.651445       2.850084
# min       -0.569231     -0.980934     -0.999047      -0.900000      -0.955556
# 25%       -0.027273     -0.016667     -0.026667      -0.057143      -0.142289
# 50%        0.000000      0.000000      0.000000       0.007032       0.014754
# 75%        0.025277      0.020161      0.038650       0.094450       0.212457
# max     1919.000119     53.000000     61.381819      57.981814      89.200000
#
#        sym_252day_ret  iwv_day0_OTC  iwv_1day_ret  iwv_5day_ret  \
# count     2265.000000   2265.000000   2265.000000   2265.000000
# mean         0.256358     -0.000014      0.000674      0.204274
# std          3.527711      0.007545      0.009363      0.407428
# ...

# %%
stock_IPO_list[['sym_day0_OTC','sym_1day_ret','sym_5day_ret','sym_22day_ret','sym_91day_ret', 'sym_252day_ret',
'iwv_day0_OTC','iwv_1day_ret', 'iwv_5day_ret','iwv_22day_ret','iwv_91day_ret','iwv_252day_ret']] .mean ()*100.
#Times it by 100 to see how it would be in perent form
#shows average returns
# Out:
# sym_day0_OTC      86.442798
# sym_1day_ret       4.127991
# sym_5day_ret       5.345202
# sym_22day_ret     10.022655
# sym_91day_ret     21.677797
# sym_252day_ret    25.635767
# iwv_day0_OTC      -0.001382
# iwv_1day_ret       0.067433
# iwv_5day_ret      20.427437
# iwv_22day_ret      1.473307
# iwv_91day_ret      5.439419
# iwv_252day_ret    11.684761
# dtype: float64

# %%
# In following codes down below will first get averages for each variable 
#Then will create column based on variable, getting average returns as a whole
#average meaning average reutnns for each variable as overall IPO and Overall Rusell 3000 etf

# %%
# Getting avergaes for first variable, times it by 100 to see the number in percent form 

avg_sym_day0_OTC=stock_IPO_list['sym_day0_OTC'].mean()*100
avg_sym_day0_OTC
# Out:
# 86.44279835600308

# %%
# Creating columns now with the new averages returns 
stock_IPO_list['SYM_day0_average']=avg_sym_day0_OTC
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/2637358968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['SYM_day0_average']=avg_sym_day0_OTC
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_sym_1day_ret=stock_IPO_list['sym_1day_ret'].mean()*100
avg_sym_1day_ret
# Out:
# 4.1279907287310476

# %%
stock_IPO_list['sym_1day_ret_average']=avg_sym_1day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/1296309585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['sym_1day_ret_average']=avg_sym_1day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_sym_5day_ret=stock_IPO_list['sym_5day_ret'].mean()*100
avg_sym_5day_ret
# Out:
# 5.345201980175302

# %%
stock_IPO_list['sym_5day_ret_average']=avg_sym_5day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/1375734160.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['sym_5day_ret_average']=avg_sym_5day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_sym_22day_ret=stock_IPO_list['sym_22day_ret'].mean()*100
avg_sym_22day_ret
# Out:
# 10.02265515889771

# %%
stock_IPO_list['sym_22day_ret_average']=avg_sym_22day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/3331868623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['sym_22day_ret_average']=avg_sym_22day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_sym_91day_ret=stock_IPO_list['sym_91day_ret'].mean()*100
avg_sym_91day_ret
# Out:
# 21.677796535061066

# %%
stock_IPO_list['sym_91day_ret_average']=avg_sym_91day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/2144141734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['sym_91day_ret_average']=avg_sym_91day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_sym_252day_ret=stock_IPO_list['sym_252day_ret'].mean()*100
avg_sym_252day_ret
# Out:
# 25.635766650784962

# %%
stock_IPO_list['sym_252day_ret_average']=avg_sym_252day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/874544439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['sym_252day_ret_average']=avg_sym_252day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_iwv_day0_OTC=stock_IPO_list['iwv_day0_OTC'].mean()*100
avg_iwv_day0_OTC
# Out:
# -0.0013817302955084474

# %%
stock_IPO_list['iwv_day0_OTC_average']=avg_iwv_day0_OTC
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/1508878764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['iwv_day0_OTC_average']=avg_iwv_day0_OTC
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_iwv_1day_ret=stock_IPO_list['iwv_1day_ret'].mean()*100

# %%
stock_IPO_list['iwv_day0_1TC_average']=avg_iwv_1day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/3766442211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['iwv_day0_1TC_average']=avg_iwv_1day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_iwv_5day_ret=stock_IPO_list['iwv_5day_ret'].mean()*100
avg_iwv_5day_ret
# Out:
# 20.427437103777994

# %%
percent = '%'
stock_IPO_list['iwv_5day_ret_average']=avg_iwv_5day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/3002657996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['iwv_5day_ret_average']=avg_iwv_5day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_iwv_22day_ret=stock_IPO_list['iwv_22day_ret'].mean()*100
avg_iwv_22day_ret
# Out:
# 1.4733066763361116

# %%
stock_IPO_list['iwv_22day_ret_average']=avg_iwv_22day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/1530742819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['iwv_22day_ret_average']=avg_iwv_22day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_iwv_91day_ret=stock_IPO_list['iwv_91day_ret'].mean()*100
avg_iwv_91day_ret
# Out:
# 5.4394185665399055

# %%
stock_IPO_list['iwv_91day_ret_average']=avg_iwv_91day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/850252503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['iwv_91day_ret_average']=avg_iwv_91day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
avg_iwv_252day_ret=stock_IPO_list['iwv_252day_ret'].mean()*100
avg_iwv_252day_ret
# Out:
# 11.68476094397624

# %%
stock_IPO_list['iwv_252day_ret_average']=avg_iwv_252day_ret
stock_IPO_list
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/664321441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['iwv_252day_ret_average']=avg_iwv_252day_ret
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# ...

# %%
#WORKING on getting differnce between average returns for  IPOS and IVW for each time horizon 
#IPOS higher rertunrs , beides 5 day return

# %%
avg_sym_day0_OTC-avg_iwv_day0_OTC
# Out:
# 86.44418008629859

# %%
avg_sym_1day_ret-avg_iwv_1day_ret
# Out:
# 4.060557903487718

# %%
avg_sym_5day_ret-avg_iwv_5day_ret
# FOR five day IWV higher returns
# Out:
# -15.082235123602691

# %%
avg_sym_22day_ret-avg_iwv_22day_ret
# Out:
# 8.549348482561598

# %%
avg_sym_91day_ret-avg_iwv_91day_ret
# Out:
# 16.23837796852116

# %%
avg_sym_252day_ret-avg_iwv_252day_ret
# Out:
# 13.951005706808722

# %% [markdown]
# # Question 1
# # Measuring the difference of returns from IPO - Iwv
# # Showing the difference of average performs in the overall market of IPOS compared to iwv
# # How much more percent returns an investors would get
# # if positve how much more percent IPO returns  compared to Iwv
# # if negative, Iwv had more higher returns in that variable or time frame

# %%
stock_IPO_list['Day 0 AVG Returns IPO VS Iwv']=avg_sym_day0_OTC-avg_iwv_day0_OTC
stock_IPO_list['Day 5 AVG Returns IPO vs Iwv']=avg_sym_5day_ret-avg_iwv_5day_ret
stock_IPO_list['Day 22 AVG Returns IPO vs Iwv']=avg_sym_22day_ret-avg_iwv_22day_ret
stock_IPO_list['Day 91 AVG Returns IPO vs Iwv']=avg_sym_91day_ret-avg_iwv_91day_ret
stock_IPO_list['Day 252 AVG Returns IPO vs Iwv']=avg_sym_252day_ret-avg_iwv_252day_ret
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/369516986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['Day 0 AVG Returns IPO VS Iwv']=avg_sym_day0_OTC-avg_iwv_day0_OTC
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/369516986.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['Day 5 AVG Returns IPO vs Iwv']=avg_sym_5day_ret-avg_iwv_5day_ret
# ...

# %%
stock_IPO_list
# included the new colums the difference average returns of IPO vs IWV
# Out:
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2322        2322   OBNK      Financial Services
# 2323        2323   NBHC      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# 2329        2329   DFHT      Financial Services
#
#                                     industry    ipo_date  sym_day0_OTC  \
# 0                         Auto Manufacturers  2018-09-12      0.100000
# 1     Drug ManufacturersÑSpecialty & Generic  2014-07-15     -0.082443
# 2                           Telecom Services  2019-04-18     -0.046154
# 3     Drug ManufacturersÑSpecialty & Generic  2019-08-01     -0.348694
# ...

# %%
import matplotlib.pylab as plt

# %%
# scatter plot sym 252 day return vs iwv 252 day return 
plt.scatter(stock_IPO_list.sym_252day_ret,stock_IPO_list.iwv_252day_ret)
plt.title('sym 252 day return vs iwv 252 day return ')
plt.xlabel('Sym day 252 returns')
plt.ylabel('Iwv 252 day Returns')
plt.show()

# %%
##Calculate average risk, Beta

# %%
#Bringing in IPO and russel data on 252 day return
ipo_1Y_ret=stock_IPO_list['sym_252day_ret']
iwv_1Y_ret=stock_IPO_list['iwv_252day_ret']
ipo_1D_ret=stock_IPO_list['sym_day0_OTC']
ipo_1Y_ret.head()
# Out:
# 0   -0.516667
# 1   -0.580699
# 2    1.420323
# 3   -0.932311
# 4    0.018280
# Name: sym_252day_ret, dtype: float64

# %%
iwv_1Y_ret.head()
# Out:
# 0    0.047296
# 1    0.092425
# 2   -0.016845
# 3    0.110416
# 4    0.210449
# Name: iwv_252day_ret, dtype: float64

# %%
IPO_nooutliers=stock_IPO_list[stock_IPO_list.sym_252day_ret<=15]
IPO_nooutliers.shape
# Out:
# (2260, 34)

# %% [markdown]
# # No outliers scatter

# %%
plt.scatter(IPO_nooutliers.sym_252day_ret, IPO_nooutliers.iwv_252day_ret)
plt.title('sym 252 day return vs iwv 252 day return ')
plt.xlabel('Sym day 252 returns')
plt.ylabel('Iwv 252 day Returns')
plt.show()

# %% [markdown]
# # Histogram plot for 252 day return  first with outliers included

# %%
stock_IPO_252_day=(stock_IPO_list.sym_252day_ret)
stock_IPO_252_day.hist()
# Out:
# <AxesSubplot:>

# %%
iwv_252_day_ret=stock_IPO_list.iwv_252day_ret
iwv_252_day_ret.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # No outliers histogram for 252 day return

# %%
IPO_nooutliers.sym_252day_ret.hist()
# Out:
# <AxesSubplot:>

# %%
# IPO_nooutliers.sym_252day_ret.shape

# %%
IPO_nooutliers.iwv_252day_ret.hist()
# Out:
# <AxesSubplot:>

# %%
#comparing the two using histogram for 252 day 
comparing_252day_ret=(IPO_nooutliers.sym_252day_ret-IPO_nooutliers.iwv_252day_ret)
comparing_252day_ret.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # no outliers comparing returns

# %%
# no outliers comparing returns 

IPO_nooutliers['252day_ret_comparision']=IPO_nooutliers.sym_252day_ret-IPO_nooutliers.iwv_252day_ret
IPO_nooutliers[['sym_252day_ret','iwv_252day_ret']].hist()
# Out:
# /var/folders/ms/qkrl3r9d2cg6rrsj1cpqsgsc0000gn/T/ipykernel_66713/3651737808.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IPO_nooutliers['252day_ret_comparision']=IPO_nooutliers.sym_252day_ret-IPO_nooutliers.iwv_252day_ret
# array([[<AxesSubplot:title={'center':'sym_252day_ret'}>,
#         <AxesSubplot:title={'center':'iwv_252day_ret'}>]], dtype=object)

# %%
#with outliers 
stock_IPO_list['1 year return with outliers']=stock_IPO_list.sym_252day_ret-stock_IPO_list.iwv_252day_ret
stock_IPO_list[['sym_252day_ret','iwv_252day_ret']].hist()
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\1514280553.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['1 year return with outliers']=stock_IPO_list.sym_252day_ret-stock_IPO_list.iwv_252day_ret
# array([[<AxesSubplot:title={'center':'sym_252day_ret'}>,
#         <AxesSubplot:title={'center':'iwv_252day_ret'}>]], dtype=object)

# %% [markdown]
# # overlapping the two histograms blue is SYM 1 year return , orange is the IWV, no outliers

# %%
# overlapping the two histograms blue is SYM 1 year return , orange is the IWV
IPO_nooutliers['sym_252day_ret'].hist()
IPO_nooutliers['iwv_252day_ret'].hist()
# Out:
# <AxesSubplot:>

# %%
IPO_nooutliers['252day_ret_comparision'].hist()
# Out:
# <AxesSubplot:>

# %%
stock_IPO_list['sym_252day_ret'].hist()
stock_IPO_list['iwv_252day_ret'].hist()
# no oraange shows up
# Out:
# <AxesSubplot:>

# %% [markdown]
# # histogram for 5 day return

# %%
stock_IPO_list['sym_5day_ret'].hist()
stock_IPO_list['iwv_5day_ret'].hist()
# Out:
# <AxesSubplot:>

# %%
stock_IPO_list['5 day return with outliers']=stock_IPO_list.sym_5day_ret-stock_IPO_list.iwv_5day_ret
stock_IPO_list[['sym_5day_ret','iwv_5day_ret']].hist()
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\1056589563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['5 day return with outliers']=stock_IPO_list.sym_5day_ret-stock_IPO_list.iwv_5day_ret
# array([[<AxesSubplot:title={'center':'sym_5day_ret'}>,
#         <AxesSubplot:title={'center':'iwv_5day_ret'}>]], dtype=object)

# %%
plt.scatter(stock_IPO_list.sym_5day_ret,stock_IPO_list.iwv_5day_ret)
plt.title('sym 5 day return vs iwv 5 day return ')
plt.xlabel('Sym day 5 day returns')
plt.ylabel('Iwv 252 5 day Returns')
plt.show()

# %%
# 5 day no outliers 
IPO_5day_nooutliers=stock_IPO_list[stock_IPO_list.sym_5day_ret<=15]
IPO_5day_nooutliers.shape
# Out:
# (2264, 36)

# %%
# plt.scatter(IPO_5day_nooutliers.sym_5day_ret, IPO_5day_nooutliers.iwv_5day_ret)
# plt.title('sym 5 day return vs iwv 5 day return ')
# plt.xlabel('Sym day 5 returns')
# plt.ylabel('Iwv 5 day Returns')
# plt.show()

# %%
IPO_5day_nooutliers=stock_IPO_list[stock_IPO_list.sym_5day_ret<=60]
IPO_5day_nooutliers.shape
# Out:
# (2264, 36)

# %%
stock_IPO_list['sym_5day_ret'].hist()
stock_IPO_list['iwv_5day_ret'].hist()
# Out:
# <AxesSubplot:>

# %%
stock_IPO_list['5 day return without outliers']=IPO_nooutliers.sym_5day_ret-IPO_5day_nooutliers.iwv_5day_ret
stock_IPO_list[['sym_5day_ret','iwv_5day_ret']].hist()
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\3930407725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['5 day return without outliers']=IPO_nooutliers.sym_5day_ret-IPO_5day_nooutliers.iwv_5day_ret
# array([[<AxesSubplot:title={'center':'sym_5day_ret'}>,
#         <AxesSubplot:title={'center':'iwv_5day_ret'}>]], dtype=object)

# %%
IPO_5day_nooutliers['sym_5day_ret'].hist()
IPO_5day_nooutliers['iwv_5day_ret'].hist()
# blue is sym 
# orange is IWV 5 day 
# IWV had better returns for 5 days compared to 1 year
# Out:
# <AxesSubplot:>

# %%
#import additional libraries
import statsmodels.formula.api as smf
import scipy.stats as scipystats
import statsmodels.api as sm
import statsmodels.stats.stattools as stools
import statsmodels.stats as stats
from statsmodels.graphics.regressionplots import *
import matplotlib.pyplot as plt

# %%
#perform regression analysis
# 
model_spy= smf.ols(' ipo_1Y_ret~ iwv_1Y_ret ', data = iwv_1Y_ret ).fit()
ipo_1D_ret['spy_pred'] = model_spy.predict()
model_spy.summary()
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\1969430603.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipo_1D_ret['spy_pred'] = model_spy.predict()
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             ipo_1Y_ret   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     7.021
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):            0.00811
# Time:                        00:26:44   Log-Likelihood:                -6065.3
# No. Observations:                2265   AIC:                         1.213e+04
# ...

# %%
spy_beta=model_spy.params[1]
print('spy_beta' ,spy_beta)
# Out:
# spy_beta 2.1760995041766567

# %%
model_spy= smf.ols(' iwv_1Y_ret~ipo_1Y_ret ', data = iwv_1Y_ret ).fit()
ipo_1D_ret['spy_pred'] = model_spy.predict()
model_spy.summary()
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\1496733329.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipo_1D_ret['spy_pred'] = model_spy.predict()
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             iwv_1Y_ret   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     7.021
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):            0.00811
# Time:                        00:26:51   Log-Likelihood:                 2240.1
# No. Observations:                2265   AIC:                            -4476.
# ...

# %%
spy_beta=model_spy.params[1]
print('spy_beta' ,spy_beta)
# Out:
# spy_beta 0.0014213408886762017

# %% [markdown]
# # Question 2
# # In the following will track different time frames/years

# %%
#Q2
# Tracking 2012-2015
#Change name  adding 2012-2015 in name
stock_IPO_list=stock_ipos
stock_IPO_2012_2015 = stock_IPO_list.loc[(stock_IPO_list['ipo_date'] < '2016-01-01-') & (stock_IPO_list['ipo_date']>'2012-01-01')]
stock_IPO_2012_2015
# Out:
#       Unnamed: 0 symbol                  sector  \
# 1              1    ACB              Healthcare
# 7              7   BABA       Consumer Cyclical
# 9              9     FB  Communication Services
# 10            10     SQ              Technology
# 11            11   SHOP              Technology
# ...          ...    ...                     ...
# 2296        2296   AVNS              Healthcare
# 2298        2298   FSBW      Financial Services
# 2309        2309   KMPH              Healthcare
# 2321        2321   HTBI      Financial Services
# 2323        2323   NBHC      Financial Services
#
#                                     industry    ipo_date  sym_day0_OTC  \
# 1     Drug ManufacturersÑSpecialty & Generic  2014-07-15     -0.082443
# 7                            Internet Retail  2014-09-19      0.012837
# 9             Internet Content & Information  2012-05-18     -0.090844
# 10                   SoftwareÑInfrastructure  2015-11-19      0.166964
# ...

# %%
AVG_2012_2015 = stock_IPO_2012_2015.mean()*100
AVG_2012_2015
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/3346421918.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   AVG_2012_2015 = stock_IPO_2012_2015.mean()*100
# Unnamed: 0        105110.139417
# sym_day0_OTC           2.217253
# sym_1day_ret           1.647748
# sym_5day_ret           3.019580
# sym_22day_ret         13.871617
# sym_91day_ret         21.588815
# sym_252day_ret        41.378576
# iwv_day0_OTC           0.006490
# iwv_1day_ret          -0.005576
# iwv_5day_ret          66.662009
# iwv_22day_ret          0.921512
# iwv_91day_ret          3.894731
# iwv_252day_ret        12.078722
# dtype: float64

# %%
#Tracking 2016-2017
stock_IPO_list=stock_ipos
stock_IPO_2016_2017 = stock_IPO_list.loc[(stock_IPO_list['ipo_date'] < '2018-01-01-') & (stock_IPO_list['ipo_date']>'2016-01-01')]
stock_IPO_2016_2017
# Out:
#       Unnamed: 0 symbol                  sector  \
# 8              8   SPCE             Industrials
# 23            23   ROKU  Communication Services
# 29            29   SNAP  Communication Services
# 39            39   NNDM              Technology
# 40            40    ZOM              Healthcare
# ...          ...    ...                     ...
# 2295        2295   TYHT              Healthcare
# 2300        2300    EHT      Financial Services
# 2301        2301   HVBC      Financial Services
# 2317        2317    GGO      Financial Services
# 2327        2327   RNDB      Financial Services
#
#                                     industry    ipo_date  sym_day0_OTC  \
# 8                        Aerospace & Defense  2017-09-29     -0.038095
# 23                             Entertainment  2017-09-28      0.487342
# 29            Internet Content & Information  2017-03-02      0.020000
# 39                         Computer Hardware  2016-03-07      0.000000
# ...

# %%
AVG_2016_2017 = stock_IPO_2016_2017.mean()*100
AVG_2016_2017
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/484202878.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   AVG_2016_2017 = stock_IPO_2016_2017.mean()*100
# Unnamed: 0        101869.148936
# sym_day0_OTC           2.285048
# sym_1day_ret           1.591641
# sym_5day_ret           4.250028
# sym_22day_ret          6.377748
# sym_91day_ret         12.557241
# sym_252day_ret        14.884506
# iwv_day0_OTC           0.008448
# iwv_1day_ret           0.091060
# iwv_5day_ret          19.902213
# iwv_22day_ret          1.634037
# iwv_91day_ret          6.371628
# iwv_252day_ret        15.637551
# dtype: float64

# %%
#Tracking 2018-2019
stock_IPO_list=stock_ipos
stock_IPO_2018_2019 = stock_IPO_list.loc[(stock_IPO_list['ipo_date'] < '2020-01-01-') & (stock_IPO_list['ipo_date']>'2018-01-01')]
stock_IPO_2018_2019
# Out:
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# 5              5   BYND      Consumer Defensive
# ...          ...    ...                     ...
# 2307        2307   RBKB      Financial Services
# 2319        2319   FINS                     NaN
# 2320        2320   CNNB      Financial Services
# 2322        2322   OBNK      Financial Services
# 2328        2328   CLBK      Financial Services
#
#                                     industry    ipo_date  sym_day0_OTC  \
# 0                         Auto Manufacturers  2018-09-12      0.100000
# 2                           Telecom Services  2019-04-18     -0.046154
# 3     Drug ManufacturersÑSpecialty & Generic  2019-08-01     -0.348694
# 4                              Biotechnology  2018-12-07     -0.154545
# ...

# %%
AVG_2018_2019 = stock_IPO_2018_2019.mean()*100
AVG_2018_2019
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/715650915.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   AVG_2018_2019 = stock_IPO_2018_2019.mean()*100
# Unnamed: 0        105613.494810
# sym_day0_OTC         334.450149
# sym_1day_ret           1.065750
# sym_5day_ret           0.966872
# sym_22day_ret          1.965591
# sym_91day_ret          0.766152
# sym_252day_ret        -0.071933
# iwv_day0_OTC          -0.013720
# iwv_1day_ret          -0.010119
# iwv_5day_ret          -4.627520
# iwv_22day_ret          0.624722
# iwv_91day_ret          1.712892
# iwv_252day_ret         8.059729
# dtype: float64

# %%
#Tracking 2020
stock_IPO_list=stock_ipos
stock_IPO_2020 = stock_IPO_list.loc[(stock_IPO_list['ipo_date'] < '2021-01-01-') & (stock_IPO_list['ipo_date']>'2020-01-01')]
stock_IPO_list
# Out:
#       Unnamed: 0 symbol                  sector  \
# 0              0    NIO       Consumer Cyclical
# 1              1    ACB              Healthcare
# 2              2     ZM  Communication Services
# 3              3   SNDL              Healthcare
# 4              4   MRNA              Healthcare
# ...          ...    ...                     ...
# 2326        2326  POWRU      Financial Services
# 2327        2327   RNDB      Financial Services
# 2328        2328   CLBK      Financial Services
# 2329        2329   DFHT      Financial Services
# 2330        2330    CAS      Financial Services
#
#                                     industry    ipo_date  sym_day0_OTC  \
# 0                         Auto Manufacturers  2018-09-12      0.100000
# 1     Drug ManufacturersÑSpecialty & Generic  2014-07-15     -0.082443
# 2                           Telecom Services  2019-04-18     -0.046154
# 3     Drug ManufacturersÑSpecialty & Generic  2019-08-01     -0.348694
# ...

# %%
AVG_2020 = stock_IPO_2020.mean()*100
AVG_2020
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/2020857158.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   AVG_2020 = stock_IPO_2020.mean()*100
# Unnamed: 0        147044.061303
# sym_day0_OTC          -0.244901
# sym_1day_ret          13.094570
# sym_5day_ret          14.497263
# sym_22day_ret         15.751844
# sym_91day_ret         51.536927
# sym_252day_ret        38.050417
# iwv_day0_OTC          -0.006698
# iwv_1day_ret           0.246638
# iwv_5day_ret         -21.334685
# iwv_22day_ret          3.131187
# iwv_91day_ret         11.229036
# iwv_252day_ret        12.255995
# dtype: float64

# %% [markdown]
# # Question 3
# # Filtering the ipo date to be before January 2021, as project requires between 2012-2020

# %%
stock_IPO_list=stock_ipos
stock_IPO_list = stock_IPO_list.loc[stock_IPO_list['ipo_date'] < '2021-01-01-']

# %%
stock_IPO_list.sector.value_counts()
# Out:
# Healthcare                653
# Financial Services        542
# Technology                256
# Consumer Cyclical         183
# Industrials               129
# Communication Services    111
# Real Estate               111
# Energy                     95
# Consumer Defensive         73
# Basic Materials            57
#                            16
# Utilities                  16
# Name: sector, dtype: int64

# %%
# Healthcare sector
stock_IPO_list.query("sector == 'Healthcare'")
# Out:
#       Unnamed: 0 symbol      sector                                industry  \
# 1              1    ACB  Healthcare  Drug ManufacturersÑSpecialty & Generic
# 3              3   SNDL  Healthcare  Drug ManufacturersÑSpecialty & Generic
# 4              4   MRNA  Healthcare                           Biotechnology
# 17            17   HEXO  Healthcare  Drug ManufacturersÑSpecialty & Generic
# 20            20    CGC  Healthcare  Drug ManufacturersÑSpecialty & Generic
# ...          ...    ...         ...                                     ...
# 2253        2253   ENTA  Healthcare                           Biotechnology
# 2277        2277   ONCR  Healthcare                           Biotechnology
# 2295        2295   TYHT  Healthcare  Drug ManufacturersÑSpecialty & Generic
# 2296        2296   AVNS  Healthcare                         Medical Devices
# 2309        2309   KMPH  Healthcare                           Biotechnology
#
# ...

# %%
Healthcare_Average = stock_IPO_list.query("sector == 'Healthcare'").mean()*100
Healthcare_Average
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/3058905637.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Healthcare_Average = stock_IPO_list.query("sector == 'Healthcare'").mean()*100
# Unnamed: 0        104580.551302
# sym_day0_OTC         295.961063
# sym_1day_ret          10.590094
# sym_5day_ret          12.125912
# sym_22day_ret         21.080968
# sym_91day_ret         36.329936
# sym_252day_ret        30.118970
# iwv_day0_OTC          -0.028137
# iwv_1day_ret           0.151153
# iwv_5day_ret          20.030483
# iwv_22day_ret          1.325697
# iwv_91day_ret          5.101980
# iwv_252day_ret        11.180825
# dtype: float64

# %%
# Financial Services Sector 
stock_IPO_list.query("sector == 'Financial Services'")
# Out:
#       Unnamed: 0 symbol              sector                       industry  \
# 19            19   PYPL  Financial Services                Credit Services
# 36            36   MARA  Financial Services                Capital Markets
# 41            41    RKT  Financial Services               Mortgage Finance
# 44            44   LMND  Financial Services  InsuranceÑProperty & Casualty
# 74            74    SBE  Financial Services                Shell Companies
# ...          ...    ...                 ...                            ...
# 2322        2322   OBNK  Financial Services                 BanksÑRegional
# 2323        2323   NBHC  Financial Services                 BanksÑRegional
# 2327        2327   RNDB  Financial Services                 BanksÑRegional
# 2328        2328   CLBK  Financial Services                 BanksÑRegional
# 2329        2329   DFHT  Financial Services                Shell Companies
#
# ...

# %%
Financial_Services_Average = stock_IPO_list.query("sector == 'Financial Services'").mean()*100
Financial_Services_Average
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/2745634397.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Financial_Services_Average = stock_IPO_list.query("sector == 'Financial Services'").mean()*100
# Unnamed: 0        161309.594096
# sym_day0_OTC           0.524626
# sym_1day_ret           0.858265
# sym_5day_ret           3.842918
# sym_22day_ret          6.046396
# sym_91day_ret         15.104759
# sym_252day_ret        36.962802
# iwv_day0_OTC           0.000309
# iwv_1day_ret           0.059317
# iwv_5day_ret           8.137919
# iwv_22day_ret          2.151238
# iwv_91day_ret          6.958039
# iwv_252day_ret        12.204565
# dtype: float64

# %%
# Technology Sector 
stock_IPO_list.query("sector == 'Technology'")
# Out:
#       Unnamed: 0 symbol      sector                         industry  \
# 10            10     SQ  Technology          SoftwareÑInfrastructure
# 11            11   SHOP  Technology             SoftwareÑApplication
# 13            13   PLTR  Technology          SoftwareÑInfrastructure
# 14            14   UBER  Technology             SoftwareÑApplication
# 22            22   WORK  Technology             SoftwareÑApplication
# ...          ...    ...         ...                              ...
# 2043        2043   CDAY  Technology             SoftwareÑApplication
# 2097        2097   CNXC  Technology  Information Technology Services
# 2134        2134   BTRS  Technology             SoftwareÑApplication
# 2212        2212    CDK  Technology             SoftwareÑApplication
# 2274        2274   BMTX  Technology             SoftwareÑApplication
#
#         ipo_date  sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  \
# ...

# %%
Technology_Average = stock_IPO_list.query("sector == 'Technology'").mean()*100
Technology_Average
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/3461749571.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Technology_Average = stock_IPO_list.query("sector == 'Technology'").mean()*100
# Unnamed: 0        81821.484375
# sym_day0_OTC          1.552610
# sym_1day_ret          1.304841
# sym_5day_ret          1.621576
# sym_22day_ret         6.405430
# sym_91day_ret        19.811310
# sym_252day_ret       36.108605
# iwv_day0_OTC         -0.018256
# iwv_1day_ret         -0.000104
# iwv_5day_ret         22.042063
# iwv_22day_ret         1.250507
# iwv_91day_ret         5.113764
# iwv_252day_ret       11.457774
# dtype: float64

# %%
# Consumer Cyclical Sector
stock_IPO_list.query("sector == 'Consumer Cyclical'")
# Out:
#       Unnamed: 0 symbol             sector            industry    ipo_date  \
# 0              0    NIO  Consumer Cyclical  Auto Manufacturers  2018-09-12
# 6              6   NKLA  Consumer Cyclical  Auto Manufacturers  2018-06-11
# 7              7   BABA  Consumer Cyclical     Internet Retail  2014-09-19
# 12            12   DKNG  Consumer Cyclical            Gambling  2019-07-25
# 18            18   NCLH  Consumer Cyclical     Travel Services  2013-01-18
# ...          ...    ...                ...                 ...         ...
# 1985        1985    MRM  Consumer Cyclical   Personal Services  2020-12-29
# 2085        2085    TMX  Consumer Cyclical   Personal Services  2014-06-26
# 2265        2265  FATBP  Consumer Cyclical         Restaurants  2020-07-14
# 2290        2290   FTDR  Consumer Cyclical   Personal Services  2018-09-13
# 2292        2292  QRTEP  Consumer Cyclical     Internet Retail  2020-09-01
#
# ...

# %%
Consumer_Average = stock_IPO_list.query("sector == 'Consumer Cyclical'").mean()*100
Consumer_Average
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/2783647957.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Consumer_Average = stock_IPO_list.query("sector == 'Consumer Cyclical'").mean()*100
# Unnamed: 0        84089.071038
# sym_day0_OTC          1.103471
# sym_1day_ret          3.710924
# sym_5day_ret          3.023810
# sym_22day_ret         3.756173
# sym_91day_ret         9.196624
# sym_252day_ret       18.142812
# iwv_day0_OTC          0.032001
# iwv_1day_ret          0.047432
# iwv_5day_ret         24.205947
# iwv_22day_ret         0.759730
# iwv_91day_ret         4.424925
# iwv_252day_ret       11.333194
# dtype: float64

# %%
# Industrials Services
stock_IPO_list.query("sector == 'Industrials'")
# Out:
#       Unnamed: 0 symbol       sector                        industry  \
# 8              8   SPCE  Industrials             Aerospace & Defense
# 37            37   KODK  Industrials     Specialty Business Services
# 100          100     BE  Industrials    Electrical Equipment & Parts
# 103          103   CTRM  Industrials                 Marine Shipping
# 129          129   UPWK  Industrials  Staffing & Employment Services
# ...          ...    ...          ...                             ...
# 2036        2036   ATKR  Industrials    Electrical Equipment & Parts
# 2058        2058    RXN  Industrials  Specialty Industrial Machinery
# 2074        2074   LXFR  Industrials  Specialty Industrial Machinery
# 2104        2104    MEC  Industrials               Metal Fabrication
# 2255        2255   AENZ  Industrials      Engineering & Construction
#
#         ipo_date  sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  \
# ...

# %%
Industrials = stock_IPO_list.query("sector == 'Industrials'").mean()*100
Industrials
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/2504142696.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Industrials = stock_IPO_list.query("sector == 'Industrials'").mean()*100
# Unnamed: 0        110102.325581
# sym_day0_OTC           2.135297
# sym_1day_ret           0.801447
# sym_5day_ret           0.851291
# sym_22day_ret          1.904147
# sym_91day_ret          7.799996
# sym_252day_ret         2.978428
# iwv_day0_OTC           0.039557
# iwv_1day_ret           0.090686
# iwv_5day_ret          31.398814
# iwv_22day_ret          1.330375
# iwv_91day_ret          4.901202
# iwv_252day_ret        12.006453
# dtype: float64

# %%
# Communication Services Sector
stock_IPO_list.query("sector == 'Communication Services'")
# Out:
#       Unnamed: 0 symbol                  sector  \
# 2              2     ZM  Communication Services
# 9              9     FB  Communication Services
# 15            15    AMC  Communication Services
# 16            16   GNUS  Communication Services
# 23            23   ROKU  Communication Services
# ...          ...    ...                     ...
# 2092        2092   HMTV  Communication Services
# 2179        2179  FWONK  Communication Services
# 2223        2223   CABO  Communication Services
# 2273        2273  LBRDK  Communication Services
# 2275        2275  LBRDA  Communication Services
#
#                             industry    ipo_date  sym_day0_OTC  sym_1day_ret  \
# 2                   Telecom Services  2019-04-18     -0.046154      0.059677
# 9     Internet Content & Information  2012-05-18     -0.090844     -0.109861
# 15                     Entertainment  2013-12-18     -0.014599      0.031217
# ...

# %%
Communication_Services = stock_IPO_list.query("sector == 'Communication Services'").mean()*100
Communication_Services
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/899509183.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Communication_Services = stock_IPO_list.query("sector == 'Communication Services'").mean()*100
# Unnamed: 0        92326.126126
# sym_day0_OTC          2.322794
# sym_1day_ret          2.604044
# sym_5day_ret          0.530450
# sym_22day_ret        -0.126482
# sym_91day_ret         0.057156
# sym_252day_ret        8.838805
# iwv_day0_OTC         -0.026051
# iwv_1day_ret         -0.130209
# iwv_5day_ret         23.524115
# iwv_22day_ret         1.414258
# iwv_91day_ret         4.638181
# iwv_252day_ret       10.893394
# dtype: float64

# %%
# Real Estate Sector
stock_IPO_list.query("sector == 'Real Estate'")
# Out:
#       Unnamed: 0 symbol       sector              industry    ipo_date  \
# 43            43    NRZ  Real Estate         REITÑMortgage  2013-05-02
# 60            60   IIPR  Real Estate       REITÑIndustrial  2016-12-01
# 118          118    WPG  Real Estate           REITÑRetail  2014-05-14
# 122          122     PK  Real Estate    REITÑHotel & Motel  2017-01-04
# 173          173   RDFN  Real Estate  Real Estate Services  2017-07-28
# ...          ...    ...          ...                   ...         ...
# 2068        2068    FSV  Real Estate  Real Estate Services  2015-06-02
# 2072        2072    BNL  Real Estate      REITÑDiversified  2020-09-17
# 2087        2087    MMI  Real Estate  Real Estate Services  2013-10-31
# 2131        2131    LFT  Real Estate         REITÑMortgage  2013-03-22
# 2231        2231    RMR  Real Estate  Real Estate Services  2015-12-14
#
#       sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  sym_91day_ret  \
# ...

# %%
RealEstate_Average = stock_IPO_list.query("sector == 'Real Estate'").mean()*100
RealEstate_Average
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/2713389071.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   RealEstate_Average = stock_IPO_list.query("sector == 'Real Estate'").mean()*100
# Unnamed: 0        107772.972973
# sym_day0_OTC           1.591612
# sym_1day_ret           0.970377
# sym_5day_ret           2.372095
# sym_22day_ret          1.045873
# sym_91day_ret          2.036616
# sym_252day_ret         8.313528
# iwv_day0_OTC           0.208387
# iwv_1day_ret           0.065814
# iwv_5day_ret          38.984669
# iwv_22day_ret          1.240537
# iwv_91day_ret          4.050833
# iwv_252day_ret        12.500877
# dtype: float64

# %%
# Energy Sector
stock_IPO_list.query("sector == 'Energy'")
# Out:
#       Unnamed: 0 symbol  sector                        industry    ipo_date  \
# 126          126    CRC  Energy                   Oil & Gas E&P  2020-10-28
# 136          136   CDEV  Energy                   Oil & Gas E&P  2016-04-15
# 143          143   BORR  Energy              Oil & Gas Drilling  2019-07-30
# 161          161   FANG  Energy                   Oil & Gas E&P  2012-10-12
# 163          163    FET  Energy  Oil & Gas Equipment & Services  2012-04-12
# ...          ...    ...     ...                             ...         ...
# 1906        1906   RNGR  Energy  Oil & Gas Equipment & Services  2017-08-11
# 1945        1945    LPG  Energy             Oil & Gas Midstream  2014-05-08
# 1948        1948    WHD  Energy  Oil & Gas Equipment & Services  2018-02-08
# 2044        2044   VTOL  Energy  Oil & Gas Equipment & Services  2013-01-22
# 2135        2135   NESR  Energy  Oil & Gas Equipment & Services  2017-06-05
#
# ...

# %%
Energy_Averages = stock_IPO_list.query("sector == 'Energy'").mean()*100
Energy_Averages
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/3947462043.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Energy_Averages = stock_IPO_list.query("sector == 'Energy'").mean()*100
# Unnamed: 0        90808.421053
# sym_day0_OTC          5.010520
# sym_1day_ret          2.452225
# sym_5day_ret          3.946903
# sym_22day_ret        24.721499
# sym_91day_ret        22.518499
# sym_252day_ret       28.595515
# iwv_day0_OTC         -0.013988
# iwv_1day_ret          0.115038
# iwv_5day_ret         41.101901
# iwv_22day_ret         1.235297
# iwv_91day_ret         4.850837
# iwv_252day_ret       13.333530
# dtype: float64

# %%
# Consumer Defensive Sector
stock_IPO_list.query("sector == 'Consumer Defensive'")
# Out:
#       Unnamed: 0 symbol              sector                       industry  \
# 5              5   BYND  Consumer Defensive                 Packaged Foods
# 82            82    KHC  Consumer Defensive                 Packaged Foods
# 87            87   COTY  Consumer Defensive  Household & Personal Products
# 92            92    VFF  Consumer Defensive                  Farm Products
# 141          141   CHGG  Consumer Defensive  Education & Training Services
# ...          ...    ...                 ...                            ...
# 1955        1955   BEDU  Consumer Defensive  Education & Training Services
# 1964        1964   POST  Consumer Defensive                 Packaged Foods
# 2016        2016   AFYA  Consumer Defensive  Education & Training Services
# 2098        2098    HLG  Consumer Defensive  Education & Training Services
# 2272        2272   VTRU  Consumer Defensive  Education & Training Services
#
# ...

# %%
Consumer_Average = stock_IPO_list.query("sector == 'Consumer Defensive'").mean()*100
Consumer_Average
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/1081788755.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Consumer_Average = stock_IPO_list.query("sector == 'Consumer Defensive'").mean()*100
# Unnamed: 0        98624.657534
# sym_day0_OTC          6.886075
# sym_1day_ret          1.706391
# sym_5day_ret          1.734012
# sym_22day_ret         4.455048
# sym_91day_ret         5.035665
# sym_252day_ret        4.033770
# iwv_day0_OTC         -0.011684
# iwv_1day_ret          0.129334
# iwv_5day_ret         18.852864
# iwv_22day_ret         1.182476
# iwv_91day_ret         5.517462
# iwv_252day_ret       11.429950
# dtype: float64

# %%
# Basic Materials Sector
stock_IPO_list.query("sector == 'Basic Materials'")
# Out:
#       Unnamed: 0 symbol           sector                          industry  \
# 121          121    PLL  Basic Materials  Other Industrial Metals & Mining
# 202          202    DOW  Basic Materials                         Chemicals
# 227          227   LTHM  Basic Materials               Specialty Chemicals
# 258          258    SVM  Basic Materials                            Silver
# 278          278     MP  Basic Materials  Other Industrial Metals & Mining
# 284          284     KL  Basic Materials                              Gold
# 380          380    PZG  Basic Materials                              Gold
# 437          437   AREC  Basic Materials                       Coking Coal
# 506          506    EQX  Basic Materials                              Gold
# 607          607   AVTR  Basic Materials               Specialty Chemicals
# 614          614   SILV  Basic Materials    Other Precious Metals & Mining
# ...

# %%
Basic_Materials_Average = stock_IPO_list.query("sector == 'Basic Materials'").mean()*100
Basic_Materials_Average
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/1855409106.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Basic_Materials_Average = stock_IPO_list.query("sector == 'Basic Materials'").mean()*100
# Unnamed: 0        115800.000000
# sym_day0_OTC           1.462341
# sym_1day_ret           1.532383
# sym_5day_ret           1.934316
# sym_22day_ret         -0.562629
# sym_91day_ret         -5.539487
# sym_252day_ret        -2.803118
# iwv_day0_OTC           0.061242
# iwv_1day_ret          -0.025314
# iwv_5day_ret          30.977027
# iwv_22day_ret          1.764116
# iwv_91day_ret          3.976599
# iwv_252day_ret        10.519300
# dtype: float64

# %%
# Utilities Sector
stock_IPO_list.query("sector == 'Utilities'")
# Out:
#       Unnamed: 0 symbol     sector                               industry  \
# 571          571   BEPC  Utilities                    UtilitiesÑRenewable
# 596          596     AY  Utilities                    UtilitiesÑRenewable
# 604          604    NEP  Utilities                    UtilitiesÑRenewable
# 687          687   CWEN  Utilities                    UtilitiesÑRenewable
# 812          812   GWRS  Utilities              UtilitiesÑRegulated Water
# 912          912    VST  Utilities  UtilitiesÑIndependent Power Producers
# 938          938   SPKE  Utilities           UtilitiesÑRegulated Electric
# 949          949   AZRE  Utilities                    UtilitiesÑRenewable
# 1008        1008   HTOO  Utilities                    UtilitiesÑRenewable
# 1134        1134    NFE  Utilities                UtilitiesÑRegulated Gas
# 1189        1189   ENIC  Utilities           UtilitiesÑRegulated Electric
# 1338        1338   BIPC  Utilities                UtilitiesÑRegulated Gas
# ...

# %%
Utilities = stock_IPO_list.query("sector == 'Utilities'").mean()*100
Utilities
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/1465944860.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Utilities = stock_IPO_list.query("sector == 'Utilities'").mean()*100
# Unnamed: 0        112100.000000
# sym_day0_OTC          -6.858543
# sym_1day_ret          -0.688317
# sym_5day_ret          -0.064018
# sym_22day_ret          4.816139
# sym_91day_ret        427.473046
# sym_252day_ret         3.426387
# iwv_day0_OTC          -0.330184
# iwv_1day_ret          -0.567924
# iwv_5day_ret          25.340712
# iwv_22day_ret          1.530925
# iwv_91day_ret          7.434890
# iwv_252day_ret         9.811288
# dtype: float64

# %%
# Stock IPO's that did not have an official sector name
stock_IPO_list.query("sector == ' '")
# Out:
#       Unnamed: 0 symbol sector         industry    ipo_date  sym_day0_OTC  \
# 24            24   SOLO                          2018-08-09     -0.261538
# 256          256    SFT         Internet Retail  2019-06-04      0.000000
# 371          371   OBLN                          2016-10-06     -0.013807
# 408          408   HSDT                          2014-06-27      0.000463
# 605          605   MOGU         Internet Retail  2018-12-06      0.166667
# 730          730   QFIN                          2018-12-14     -0.018441
# 896          896   SPPP                          2012-12-19      0.044304
# 900          900   AACQ                          2020-09-04      0.000000
# 1645        1645    VXZ                          2018-01-25      0.000000
# 1719        1719  AACQU                          2020-07-14     -0.006718
# 1766        1766   FSDC                          2020-08-12      0.003899
# 1926        1926    LDP                          2012-07-30     -0.007921
# ...

# %%
NoSector_Average = stock_IPO_list.query("sector == ' '").mean()*100
NoSector_Average
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/1845746391.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   NoSector_Average = stock_IPO_list.query("sector == ' '").mean()*100
# Unnamed: 0        122525.000000
# sym_day0_OTC          -1.124063
# sym_1day_ret           1.108125
# sym_5day_ret           4.853433
# sym_22day_ret         15.663656
# sym_91day_ret         14.336475
# sym_252day_ret        41.348836
# iwv_day0_OTC          -0.260538
# iwv_1day_ret          -0.304010
# iwv_5day_ret          21.225429
# iwv_22day_ret          1.159124
# iwv_91day_ret          7.934555
# iwv_252day_ret        14.146794
# dtype: float64

# %% [markdown]
# # Question 4 getting list of S&P 500 stocks, and seeing how many IPOS are included in the S&P 500, and seeing how performance is different from all IPO's

# %%
snp_list=pd.read_csv('snp500_list.csv')

# %%
len(snp_list)
# getting length/ how many symbols are in the SNP_500
# Out:
# 505

# %%
len(stock_IPO_list)
#getting length/ how many sybols are in the stock ipos
# Out:
# 2265

# %%
# how many stocks are in both lists for SNP 500 and stock ipos 
#naming it both lists SNP 500 _ stock ipos, because we are seeing what stocks are in both 
# shows us what stocks are in both 
both_list_SNP500_Stock_IPOS= list(set(snp_list['symbol'])  & set(stock_IPO_list['symbol']))
both_list_SNP500_Stock_IPOS
# Out:
# ['DOW',
#  'IR',
#  'WRK',
#  'LW',
#  'FANG',
#  'FB',
#  'TWTR',
#  'CDW',
#  'PSX',
#  'KHC',
#  'ABBV',
#  'ANET',
#  'CZR',
#  'KEYS',
#  'NWS',
#  'HPE',
#  'HLT',
#  'CTVA',
#  'ALLE',
#  'FOX',
#  'PAYC',
#  'IQV',
#  'AMCR',
#  'NOW',
#  'CFG',
#  'CTLT',
#  'ZTS',
#  'QRVO',
#  'ENPH',
#  'FTV',
#  'PYPL',
#  'ETSY',
#  'INFO',
#  'NWSA',
#  'CARR',
#  'OTIS',
#  'FOXA',
#  'UA',
#  'SYF',
#  'NCLH']

# %%
len(both_list_SNP500_Stock_IPOS) # how many IPOS are in SPX
# Out:
# 40

# %%
list(both_list_SNP500_Stock_IPOS)
# Out:
# ['DOW',
#  'IR',
#  'WRK',
#  'LW',
#  'FANG',
#  'FB',
#  'TWTR',
#  'CDW',
#  'PSX',
#  'KHC',
#  'ABBV',
#  'ANET',
#  'CZR',
#  'KEYS',
#  'NWS',
#  'HPE',
#  'HLT',
#  'CTVA',
#  'ALLE',
#  'FOX',
#  'PAYC',
#  'IQV',
#  'AMCR',
#  'NOW',
#  'CFG',
#  'CTLT',
#  'ZTS',
#  'QRVO',
#  'ENPH',
#  'FTV',
#  'PYPL',
#  'ETSY',
#  'INFO',
#  'NWSA',
#  'CARR',
#  'OTIS',
#  'FOXA',
#  'UA',
#  'SYF',
#  'NCLH']

# %%
for i in range(2265,len(stock_IPO_list)):
    print(stock_IPO_list.symbol[i])

# %%
#list of SNP symbols
sp_symbols= list(snp_list.symbol)
sp_symbols
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABMD',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFL',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALXN',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANET',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATO',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BF.B',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLK',
#  'BLL',
#  'BMY',
#  'BR',
#  'BRK.B',
#  'BSX',
#  'BWA',
#  'BXP',
#  'C',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCI',
#  'CCL',
#  'CDNS',
#  'CDW',
#  'CE',
#  'CERN',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
#  'CMA',
# ...

# %%
import numpy as np

# %%
stock_IPO_list['sp'] = np.where(stock_IPO_list['symbol'].isin(sp_symbols), 'in', 'out')
stock_IPO_list['sp']
# have to make sure its before 2021, and length is 2265
#stocks in meaning what stock ipos are in SNP list
#stocks out meaning what stocks ipos are not on IPO list
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\2479972976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['sp'] = np.where(stock_IPO_list['symbol'].isin(sp_symbols), 'in', 'out')
# 0       out
# 1       out
# 2       out
# 3       out
# 4       out
#        ...
# 2322    out
# 2323    out
# 2327    out
# 2328    out
# 2329    out
# Name: sp, Length: 2265, dtype: object

# %%
stock_IPO_list['sp'].value_counts()
# adjusted for time frame 2020 changed name to stock IPO list cause earlier in the code adjsuted to the right time frame
# total of stocks are 2265 
#40 of stock IPOs are in SNP 500
# Out:
# out    2225
# in       40
# Name: sp, dtype: int64

# %%
stock_IPO_list.columns
# Out:
# Index(['Unnamed: 0', 'symbol', 'sector', 'industry', 'ipo_date',
#        'sym_day0_OTC', 'sym_1day_ret', 'sym_5day_ret', 'sym_22day_ret',
#        'sym_91day_ret', 'sym_252day_ret', 'iwv_day0_OTC', 'iwv_1day_ret',
#        'iwv_5day_ret', 'iwv_22day_ret', 'iwv_91day_ret', 'iwv_252day_ret',
#        'SYM_day0_average', 'sym_1day_ret_average', 'sym_5day_ret_average',
#        'sym_22day_ret_average', 'sym_91day_ret_average',
#        'sym_252day_ret_average', 'iwv_day0_OTC_average',
#        'iwv_day0_1TC_average', 'iwv_5day_ret_average', 'iwv_22day_ret_average',
#        'iwv_91day_ret_average', 'iwv_252day_ret_average',
#        'Day 0 AVG Returns IPO VS Iwv', 'Day 5 AVG Returns IPO vs Iwv',
#        'Day 22 AVG Returns IPO vs Iwv', 'Day 91 AVG Returns IPO vs Iwv',
#        'Day 252 AVG Returns IPO vs Iwv', '1 year return with outliers',
#        '5 day return with outliers', '5 day return without outliers', 'sp'],
#       dtype='object')

# %% [markdown]
# # measuring performance of stock ipos in SNP 500 and out

# %%
stock_IPO_list.groupby('sp')['sym_day0_OTC','sym_1day_ret','sym_5day_ret'].agg(('mean', 'std' , 'median' , 'count'))
# measuring sym day 0 otc, sym 1 day ret and 5 day ret of both in and out
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\2522190307.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   stock_IPO_list.groupby('sp')['sym_day0_OTC','sym_1day_ret','sym_5day_ret'].agg(('mean', 'std' , 'median' , 'count'))
#     sym_day0_OTC                            sym_1day_ret                   \
#             mean        std    median count         mean       std median
# sp
# in     -0.008025   0.047086 -0.002769    40     0.000506  0.039875    0.0
# out     0.880113  40.682852  0.000000  2225     0.042013  1.140550    0.0
#
#           sym_5day_ret
#     count         mean       std    median count
# sp
# in     40     0.011029  0.068350  0.012155    40
# out  2225     0.054215  1.337938  0.000000  2225

# %%
stock_IPO_list.groupby('sp')['sym_22day_ret','sym_91day_ret','sym_252day_ret'].agg(('mean', 'std' , 'median' , 'count'))
# shows mean std median and count
#grouping by 22 day_ret # and 91 day and 252 day ret
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/1691741265.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   stock_IPO_list.groupby('sp')['sym_22day_ret','sym_91day_ret','sym_252day_ret'].agg(('mean', 'std' , 'median' , 'count'))
#     sym_22day_ret                           sym_91day_ret                      \
#              mean       std    median count          mean       std    median
# sp
# in       0.027181  0.121525  0.032120    40      0.090870  0.283175  0.071237
# out      0.101540  1.666123  0.006796  2225      0.219041  2.875305  0.014435
#
#           sym_252day_ret
#     count           mean       std    median count
# sp
# in     40       0.256513  0.543028  0.146633    40
# out  2225       0.256355  3.558567  0.010256  2225

# %% [markdown]
# # Question 5 -  Getting list of Russell-1000 stocks, and seeing how many IPOS are included in the Russell-1000, and seeing how performance is different from all IPO's

# %%
Russell_factors=pd.read_csv('russell_Factors_20210124.csv')

# %%
Russell_1000=pd.DataFrame(Russell_factors)

# %%
Russell_1000
# Out:
#      Unnamed: 0 symbol           sector  \
# 0             0    APD  Basic Materials
# 1             1    ALB  Basic Materials
# 2             2    ASH  Basic Materials
# 3             3   AVTR  Basic Materials
# 4             4   AXTA  Basic Materials
# ..          ...    ...              ...
# 978         979     SO        Utilities
# 979         980    UGI        Utilities
# 980         981    VST        Utilities
# 981         982    WEC        Utilities
# 982         983    XEL        Utilities
#
#                                   industry     marketCap  averageVolume  \
# 0                                Chemicals  6.268950e+10        1308609
# 1                      Specialty Chemicals  1.849265e+10        1433977
# 2                      Specialty Chemicals  5.194364e+09         495904
# 3                      Specialty Chemicals  1.765091e+10        5315691
# 4                      Specialty Chemicals  6.492101e+09        2289027
# ...

# %%
both_list_Russell_Stock_IPOs= list(set(Russell_1000['symbol'])  & set(stock_IPO_list['symbol']))
both_list_Russell_Stock_IPOs
# Out:
# ['DBX',
#  'FWONK',
#  'GRUB',
#  'LBRDK',
#  'Z',
#  'TWTR',
#  'SPOT',
#  'PSX',
#  'SABR',
#  'UBER',
#  'ABBV',
#  'GLOB',
#  'NEWR',
#  'BPYU',
#  'CZR',
#  'ENR',
#  'PCTY',
#  'STNE',
#  'POST',
#  'CVNA',
#  'SYNH',
#  'LSXMA',
#  'REXR',
#  'SWCH',
#  'PK',
#  'CTVA',
#  'FSLY',
#  'TWLO',
#  'JBGS',
#  'TXG',
#  'SAIC',
#  'FWONA',
#  'MSGE',
#  'SNDR',
#  'LBRDA',
#  'PTON',
#  'SPLK',
#  'ESTC',
#  'VRT',
#  'ROKU',
#  'INVH',
#  'AYX',
#  'NOW',
#  'VVV',
#  'CTLT',
#  'GLPI',
#  'UNVR',
#  'W',
#  'XLRN',
#  'ZTS',
#  'VEEV',
#  'FTV',
#  'PYPL',
#  'GBT',
#  'ZEN',
#  'APLE',
#  'SRC',
#  'CG',
#  'AVTR',
#  'EAF',
#  'FIVE',
#  'EQH',
#  'NCLH',
#  'WH',
#  'FND',
#  'NET',
#  'LYFT',
#  'GMED',
#  'VICI',
#  'FTDR',
#  'NVT',
#  'DOCU',
#  'LITE',
#  'WRK',
#  'DOW',
#  'SWI',
#  'ARD',
#  'TW',
#  'TNDM',
#  'BHF',
#  'CDW',
#  'PEN',
#  'PGRE',
#  'VST',
#  'MDLA',
#  'NWS',
#  'COMM',
#  'TTD',
#  'GH',
#  'FOX',
#  'PLNT',
#  'OLLI',
#  'ELAN',
#  'PAYC',
# ...

# %%
both_list_Russell_Stock_IPOs_ROA= list(set(Russell_1000['symbol'])  & set(stock_IPO_list['symbol']))
both_list_Russell_Stock_IPOs
# Out:
# ['DBX',
#  'FWONK',
#  'GRUB',
#  'LBRDK',
#  'Z',
#  'TWTR',
#  'SPOT',
#  'PSX',
#  'SABR',
#  'UBER',
#  'ABBV',
#  'GLOB',
#  'NEWR',
#  'BPYU',
#  'CZR',
#  'ENR',
#  'PCTY',
#  'STNE',
#  'POST',
#  'CVNA',
#  'SYNH',
#  'LSXMA',
#  'REXR',
#  'SWCH',
#  'PK',
#  'CTVA',
#  'FSLY',
#  'TWLO',
#  'JBGS',
#  'TXG',
#  'SAIC',
#  'FWONA',
#  'MSGE',
#  'SNDR',
#  'LBRDA',
#  'PTON',
#  'SPLK',
#  'ESTC',
#  'VRT',
#  'ROKU',
#  'INVH',
#  'AYX',
#  'NOW',
#  'VVV',
#  'CTLT',
#  'GLPI',
#  'UNVR',
#  'W',
#  'XLRN',
#  'ZTS',
#  'VEEV',
#  'FTV',
#  'PYPL',
#  'GBT',
#  'ZEN',
#  'APLE',
#  'SRC',
#  'CG',
#  'AVTR',
#  'EAF',
#  'FIVE',
#  'EQH',
#  'NCLH',
#  'WH',
#  'FND',
#  'NET',
#  'LYFT',
#  'GMED',
#  'VICI',
#  'FTDR',
#  'NVT',
#  'DOCU',
#  'LITE',
#  'WRK',
#  'DOW',
#  'SWI',
#  'ARD',
#  'TW',
#  'TNDM',
#  'BHF',
#  'CDW',
#  'PEN',
#  'PGRE',
#  'VST',
#  'MDLA',
#  'NWS',
#  'COMM',
#  'TTD',
#  'GH',
#  'FOX',
#  'PLNT',
#  'OLLI',
#  'ELAN',
#  'PAYC',
# ...

# %%
#212 stocks in russell 1000 and stock ipos 
len(both_list_Russell_Stock_IPOs)
# Out:
# 212

# %%
list(both_list_Russell_Stock_IPOs)
# Out:
# ['DBX',
#  'FWONK',
#  'GRUB',
#  'LBRDK',
#  'Z',
#  'TWTR',
#  'SPOT',
#  'PSX',
#  'SABR',
#  'UBER',
#  'ABBV',
#  'GLOB',
#  'NEWR',
#  'BPYU',
#  'CZR',
#  'ENR',
#  'PCTY',
#  'STNE',
#  'POST',
#  'CVNA',
#  'SYNH',
#  'LSXMA',
#  'REXR',
#  'SWCH',
#  'PK',
#  'CTVA',
#  'FSLY',
#  'TWLO',
#  'JBGS',
#  'TXG',
#  'SAIC',
#  'FWONA',
#  'MSGE',
#  'SNDR',
#  'LBRDA',
#  'PTON',
#  'SPLK',
#  'ESTC',
#  'VRT',
#  'ROKU',
#  'INVH',
#  'AYX',
#  'NOW',
#  'VVV',
#  'CTLT',
#  'GLPI',
#  'UNVR',
#  'W',
#  'XLRN',
#  'ZTS',
#  'VEEV',
#  'FTV',
#  'PYPL',
#  'GBT',
#  'ZEN',
#  'APLE',
#  'SRC',
#  'CG',
#  'AVTR',
#  'EAF',
#  'FIVE',
#  'EQH',
#  'NCLH',
#  'WH',
#  'FND',
#  'NET',
#  'LYFT',
#  'GMED',
#  'VICI',
#  'FTDR',
#  'NVT',
#  'DOCU',
#  'LITE',
#  'WRK',
#  'DOW',
#  'SWI',
#  'ARD',
#  'TW',
#  'TNDM',
#  'BHF',
#  'CDW',
#  'PEN',
#  'PGRE',
#  'VST',
#  'MDLA',
#  'NWS',
#  'COMM',
#  'TTD',
#  'GH',
#  'FOX',
#  'PLNT',
#  'OLLI',
#  'ELAN',
#  'PAYC',
# ...

# %%
for i in range(2265,len(stock_IPO_list)):
    print(stock_IPO_list.symbol[i])

# %%
Russ_symbols=list(Russell_1000.symbol)
Russ_symbols
# Out:
# ['APD',
#  'ALB',
#  'ASH',
#  'AVTR',
#  'AXTA',
#  'CBT',
#  'CE',
#  'CF',
#  'CTVA',
#  'DOW',
#  'DD',
#  'EXP',
#  'EMN',
#  'ECL',
#  'ESI',
#  'FMC',
#  'FCX',
#  'GRA',
#  'HUN',
#  'IFF',
#  'LIN',
#  'LYB',
#  'MLM',
#  'MDU',
#  'MOS',
#  'NEU',
#  'NEM',
#  'NUE',
#  'OLN',
#  'PPG',
#  'RS',
#  'RGLD',
#  'SMG',
#  'SHW',
#  'SCCO',
#  'STLD',
#  'CC',
#  'UNVR',
#  'VMC',
#  'WLK',
#  'ATVI',
#  'GOOGL',
#  'GOOG',
#  'ATUS',
#  'T',
#  'CABO',
#  'CHTR',
#  'CMCSA',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DIS',
#  'EA',
#  'FB',
#  'FOXA',
#  'FOX',
#  'GRUB',
#  'IAC',
#  'IPG',
#  'LBRDA',
#  'LBRDK',
#  'FWONA',
#  'FWONK',
#  'LSXMA',
#  'LSXMK',
#  'LGF-A',
#  'LGF-B',
#  'LYV',
#  'MSGS',
#  'MSGE',
#  'MTCH',
#  'NFLX',
#  'NYT',
#  'NWSA',
#  'NWS',
#  'NXST',
#  'OMC',
#  'PINS',
#  'ROKU',
#  'SIRI',
#  'SPOT',
#  'TMUS',
#  'TTWO',
#  'TDS',
#  'TWLO',
#  'TWTR',
#  'USM',
#  'VZ',
#  'VIACA',
#  'VIAC',
#  'JW-A',
#  'WWE',
#  'ZG',
#  'Z',
#  'ZM',
# ...

# %%
import numpy as np

# %%
stock_IPO_list['sp'] = np.where(stock_IPO_list['symbol'].isin(Russ_symbols), 'in', 'out')
stock_IPO_list['sp']
# what stocks ipos are also in the Russell 1000 list
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\1020695757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_IPO_list['sp'] = np.where(stock_IPO_list['symbol'].isin(Russ_symbols), 'in', 'out')
# 0       out
# 1       out
# 2        in
# 3       out
# 4        in
#        ...
# 2322    out
# 2323    out
# 2327    out
# 2328    out
# 2329    out
# Name: sp, Length: 2265, dtype: object

# %%
stock_IPO_list['sp'].value_counts()
#212 stock ipos are in Russell 1000 and 2053 are out or not on list
# Out:
# out    2053
# in      212
# Name: sp, dtype: int64

# %%
# looking at return horizons 
stock_IPO_list.groupby('sp')['sym_day0_OTC','sym_1day_ret','sym_5day_ret'].agg(('mean', 'std' , 'median' , 'count'))
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\3960582102.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   stock_IPO_list.groupby('sp')['sym_day0_OTC','sym_1day_ret','sym_5day_ret'].agg(('mean', 'std' , 'median' , 'count'))
#     sym_day0_OTC                         sym_1day_ret                         \
#             mean        std median count         mean       std median count
# sp
# in      0.011400   0.088994    0.0   212     0.006507  0.065445    0.0   212
# out     0.952515  42.352768    0.0  2053     0.044871  1.187172    0.0  2053
#
#     sym_5day_ret
#             mean       std    median count
# sp
# in      0.015813  0.088621  0.009065   212
# out     0.057339  1.392580  0.000000  2053

# %%
stock_IPO_list.groupby('sp')['sym_22day_ret','sym_91day_ret','sym_252day_ret'].agg(('mean', 'std' , 'median' , 'count'))
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\1153211947.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   stock_IPO_list.groupby('sp')['sym_22day_ret','sym_91day_ret','sym_252day_ret'].agg(('mean', 'std' , 'median' , 'count'))
#     sym_22day_ret                           sym_91day_ret                      \
#              mean       std    median count          mean       std    median
# sp
# in       0.035461  0.152184  0.014440   212      0.104042  0.301077  0.065773
# out      0.106914  1.733833  0.006255  2053      0.228419  2.991893  0.012371
#
#           sym_252day_ret
#     count           mean       std    median count
# sp
# in    212       0.295394  0.547291  0.212405   212
# out  2053       0.252327  3.701282  0.001003  2053

# %%
ipo_symbols=list(stock_IPO_list.symbol)

# %%
Russell_1000['sp']=np.where(Russell_1000['symbol'].isin(ipo_symbols), 'in', 'out')
Russell_1000.head()
# Out:
#    Unnamed: 0 symbol           sector             industry     marketCap  \
# 0           0    APD  Basic Materials            Chemicals  6.268950e+10
# 1           1    ALB  Basic Materials  Specialty Chemicals  1.849265e+10
# 2           2    ASH  Basic Materials  Specialty Chemicals  5.194364e+09
# 3           3   AVTR  Basic Materials  Specialty Chemicals  1.765091e+10
# 4           4   AXTA  Basic Materials  Specialty Chemicals  6.492101e+09
#
#    averageVolume      beta  trailingPE  pegRatio  \
# 0        1308609  0.794117   33.419750      2.98
# 1        1433977  1.596638   48.387188      3.00
# 2         495904  1.342436         NaN      1.05
# 3        5315691       NaN  256.470580      1.39
# 4        2289027  1.474264   69.097750      6.91
#
#    priceToSalesTrailing12Months  ...     bid     ask  bidSize  askSize    ROA  \
# 0                      7.078520  ...  278.01  287.75      900      800  6.37%
# ...

# %%
Russell_1000['sp'].value_counts()
# Out:
# out    771
# in     212
# Name: sp, dtype: int64

# %%
# 212 Rusell 1000 stocks are stock IPOS, 771 are not

# %%
Russ_symbols
# Out:
# ['APD',
#  'ALB',
#  'ASH',
#  'AVTR',
#  'AXTA',
#  'CBT',
#  'CE',
#  'CF',
#  'CTVA',
#  'DOW',
#  'DD',
#  'EXP',
#  'EMN',
#  'ECL',
#  'ESI',
#  'FMC',
#  'FCX',
#  'GRA',
#  'HUN',
#  'IFF',
#  'LIN',
#  'LYB',
#  'MLM',
#  'MDU',
#  'MOS',
#  'NEU',
#  'NEM',
#  'NUE',
#  'OLN',
#  'PPG',
#  'RS',
#  'RGLD',
#  'SMG',
#  'SHW',
#  'SCCO',
#  'STLD',
#  'CC',
#  'UNVR',
#  'VMC',
#  'WLK',
#  'ATVI',
#  'GOOGL',
#  'GOOG',
#  'ATUS',
#  'T',
#  'CABO',
#  'CHTR',
#  'CMCSA',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DIS',
#  'EA',
#  'FB',
#  'FOXA',
#  'FOX',
#  'GRUB',
#  'IAC',
#  'IPG',
#  'LBRDA',
#  'LBRDK',
#  'FWONA',
#  'FWONK',
#  'LSXMA',
#  'LSXMK',
#  'LGF-A',
#  'LGF-B',
#  'LYV',
#  'MSGS',
#  'MSGE',
#  'MTCH',
#  'NFLX',
#  'NYT',
#  'NWSA',
#  'NWS',
#  'NXST',
#  'OMC',
#  'PINS',
#  'ROKU',
#  'SIRI',
#  'SPOT',
#  'TMUS',
#  'TTWO',
#  'TDS',
#  'TWLO',
#  'TWTR',
#  'USM',
#  'VZ',
#  'VIACA',
#  'VIAC',
#  'JW-A',
#  'WWE',
#  'ZG',
#  'Z',
#  'ZM',
# ...

# %%
Russell_1000.columns
# Out:
# Index(['Unnamed: 0', 'symbol', 'sector', 'industry', 'marketCap',
#        'averageVolume', 'beta', 'trailingPE', 'pegRatio',
#        'priceToSalesTrailing12Months', 'priceTobook', 'profitMargins',
#        'sharesOutstanding', 'shortRatio', 'floatShares', 'bid', 'ask',
#        'bidSize', 'askSize', 'ROA', 'ROE', 'payoutR', 'DtoEQ', 'g_nxt5', 'sp'],
#       dtype='object')

# %%
Russell_1000.groupby('sp')['marketCap','beta',].agg(('mean', 'std' , 'median' , 'count'))
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\1238684183.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Russell_1000.groupby('sp')['marketCap','beta',].agg(('mean', 'std' , 'median' , 'count'))
#         marketCap                                        beta            \
#              mean           std        median count      mean       std
# sp
# in   2.312644e+10  6.001513e+10  1.050144e+10   212  1.332155  0.590354
# out  4.712646e+10  1.489521e+11  1.498654e+10   771  1.159313  0.543385
#
#
#        median count
# sp
# in   1.278886   177
# out  1.119747   765

# %%
Russell_1000.groupby('sp')['trailingPE', 'pegRatio', 'priceToSalesTrailing12Months',].agg(('mean', 'std' , 'median' , 'count'))
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\63150227.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Russell_1000.groupby('sp')['trailingPE', 'pegRatio', 'priceToSalesTrailing12Months',].agg(('mean', 'std' , 'median' , 'count'))
#      trailingPE                                pegRatio                    \
#            mean          std     median count      mean        std median
# sp
# in   347.722651  1414.383475  52.375534   100  5.571777  43.949932   1.71
# out   48.047426   129.429695  27.893445   634  5.411045  44.572551   2.29
#
#           priceToSalesTrailing12Months
#     count                         mean         std    median count
# sp
# in    197                    90.100360  755.020083  5.715632   210
# out   756                     4.956527    6.837971  3.135821   768

# %%
Russell_1000.groupby('sp')['priceTobook', 'profitMargins',
       'sharesOutstanding', 'shortRatio'].agg(('mean', 'std' , 'median' , 'count'))
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\2966058885.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Russell_1000.groupby('sp')['priceTobook', 'profitMargins',
#     priceTobook                  profitMargins                            \
#            mean std median count          mean       std    median count
# sp
# in          NaN NaN    NaN     0      0.049969  1.392894  0.003895   212
# out         NaN NaN    NaN     0      0.092263  0.350755  0.097580   769
#
#     sharesOutstanding                                  shortRatio            \
#                  mean           std       median count       mean       std
# sp
# in       2.479569e+08  3.075016e+08  158808000.0   212   4.297830  3.168398
# out      4.254290e+08  9.742206e+08  169523008.0   769   3.566281  2.679728
#
#
#     median count
# sp
# in    3.33   212
# out   2.75   769

# %%
Russell_1000.groupby('sp')['floatShares', 'bid', 'ask',
       'bidSize', 'askSize'].agg(('mean', 'std' , 'median' , 'count'))
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\2921211834.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Russell_1000.groupby('sp')['floatShares', 'bid', 'ask',
#       floatShares                                          bid              \
#              mean           std       median count        mean         std
# sp
# in   2.261111e+08  2.873062e+08  140134781.5   212  100.290425  112.170843
# out  4.045230e+08  9.571283e+08  161022431.0   769  149.532023  289.113934
#
#                           ask                               bidSize  \
#      median count        mean         std median count         mean
# sp
# in   54.715   212  115.011792  175.573259  62.35   212  1243.867925
# out  85.680   771  158.607367  305.946702  89.00   771  1429.831388
#
#                                     askSize
#              std  median count         mean          std median count
# sp
# ...

# %%
for f in Russell_1000.columns:
    strng = str( Russell_1000[f][0] )
    if '%' in strng:
        print(f)
# Out:
# ROA
# ROE
# payoutR
# g_nxt5

# %%
percent=['ROA','ROE', 'payoutR', 'g_nxt5']
for f in percent:
    Russell_1000[f] = Russell_1000[f].str[0:-1]
    Russell_1000[f] = pd.to_numeric( Russell_1000[f], errors='coerce' ) /100
Russell_1000[percent].head()
# Out:
#       ROA     ROE  payoutR  g_nxt5
# 0  0.0637  0.1633   0.6058  0.1031
# 1  0.0426  0.1082   0.4241  0.1500
# 2  0.0171 -0.1486      NaN  0.1909
# 3  0.0406  0.0553   0.0000  0.2488
# 4  0.0360  0.0689   0.0000  0.0352

# %%
Russell_1000[f] = pd.to_numeric( Russell_1000[f], errors='coerce' ) /100
Russell_1000[percent].head()
# Out:
#       ROA     ROE  payoutR    g_nxt5
# 0  0.0637  0.1633   0.6058  0.001031
# 1  0.0426  0.1082   0.4241  0.001500
# 2  0.0171 -0.1486      NaN  0.001909
# 3  0.0406  0.0553   0.0000  0.002488
# 4  0.0360  0.0689   0.0000  0.000352

# %%
Russell_1000.shape
# Out:
# (983, 25)

# %%
Russell_1000[percent].isnull().sum()
# Out:
# ROA         13
# ROE         44
# payoutR    122
# g_nxt5      29
# dtype: int64

# %%
Russell_1000_= Russell_1000[['symbol', 'sp']+percent] .dropna()
Russell_1000_.head()
# Out:
#   symbol   sp     ROA     ROE  payoutR    g_nxt5
# 0    APD  out  0.0637  0.1633   0.6058  0.001031
# 1    ALB  out  0.0426  0.1082   0.4241  0.001500
# 3   AVTR   in  0.0406  0.0553   0.0000  0.002488
# 4   AXTA   in  0.0360  0.0689   0.0000  0.000352
# 6     CE  out  0.0445  0.1972   0.4990  0.000590

# %%
Russell_1000_.groupby('sp')['ROA', 'ROE', 'payoutR', 'g_nxt5'].agg(('mean', 'std' , 'median' , 'count'))
# measuring ROA, ROE,payout R, gnext5
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6320\2571272131.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Russell_1000_.groupby('sp')['ROA', 'ROE', 'payoutR', 'g_nxt5'].agg(('mean', 'std' , 'median' , 'count'))
#           ROA                               ROE                           \
#          mean       std  median count      mean       std   median count
# sp
# in   0.001857  0.074376  0.0148   156 -0.024294  0.370995  0.02985   156
# out  0.052450  0.048736  0.0458   641  0.394022  2.693509  0.12880   641
#
#       payoutR                            g_nxt5
#          mean       std  median count      mean       std    median count
# sp
# in   0.441887  2.622247  0.0000   156  0.001752  0.006329  0.001289   156
# out  0.640604  1.939692  0.3185   641  0.001119  0.002447  0.000840   641

# %% [markdown]
# # Question 6

# %%
ETF_ipos = pd.read_csv('etfs_ipos.csv')

# %%
df_ETF_ipos=pd.DataFrame(ETF_ipos)
df_ETF_ipos
# Out:
#       Unnamed: 0 symbol sector industry    ipo_date  sym_day0_OTC  \
# 0              0    SFY                  2019-04-11      0.003006
# 1              1   SPGM                  2012-03-05      0.000000
# 2              2   SFYX                  2019-04-11      0.003000
# 3              3   GIGE                  2019-05-08     -0.001497
# 4              4   TGIF                  2020-10-02      0.000920
# ...          ...    ...    ...      ...         ...           ...
# 1116        1116   INFL                  2021-01-12      0.003577
# 1117        1117   CEMB                  2012-04-19      0.000000
# 1118        1118   DVLU                  2018-10-18     -0.034211
# 1119        1119   LYFE                  2020-11-18     -0.011783
# 1120        1120   GBDV                  2019-12-27     -0.002987
#
#       sym_1day_ret  sym_5day_ret  sym_22day_ret  sym_91day_ret  \
# 0         0.005994      0.002997      -0.025475       0.009234
# ...

# %%
df_ETF_ipos.describe()
# Out:
#         Unnamed: 0  sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  \
# count  1121.000000   1121.000000   1121.000000   1121.000000    1121.000000
# mean    560.000000     -0.001785      0.000330      0.022855       0.030385
# std     323.749131      0.013302      0.014244      0.722216       0.728815
# min       0.000000     -0.327931     -0.105343     -0.246645      -0.440298
# 25%     280.000000     -0.002382     -0.002778     -0.005691      -0.011442
# 50%     560.000000      0.000000      0.000000      0.000401       0.006624
# 75%     840.000000      0.000899      0.003395      0.009646       0.033154
# max    1120.000000      0.047059      0.199471     24.166669      24.333335
#
#        sym_91day_ret  sym_252day_ret  iwv_day0_OTC  iwv_1day_ret  \
# count    1121.000000     1121.000000   1121.000000   1121.000000
# mean        0.047481        0.086627     -0.000124      0.000557
# std         0.776769        0.920198      0.008314      0.009652
# ...

# %%
df_ETF_ipos[['sym_day0_OTC','sym_1day_ret','sym_5day_ret','sym_22day_ret','sym_91day_ret', 'sym_252day_ret',
'iwv_day0_OTC','iwv_1day_ret', 'iwv_5day_ret','iwv_22day_ret','iwv_91day_ret','iwv_252day_ret']] .describe ()
# Out:
#        sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  sym_91day_ret  \
# count   1121.000000   1121.000000   1121.000000    1121.000000    1121.000000
# mean      -0.001785      0.000330      0.022855       0.030385       0.047481
# std        0.013302      0.014244      0.722216       0.728815       0.776769
# min       -0.327931     -0.105343     -0.246645      -0.440298      -0.817892
# 25%       -0.002382     -0.002778     -0.005691      -0.011442      -0.017030
# 50%        0.000000      0.000000      0.000401       0.006624       0.021804
# 75%        0.000899      0.003395      0.009646       0.033154       0.069730
# max        0.047059      0.199471     24.166669      24.333335      25.666668
#
#        sym_252day_ret  iwv_day0_OTC  iwv_1day_ret  iwv_5day_ret  \
# count     1121.000000   1121.000000   1121.000000   1121.000000
# mean         0.086627     -0.000124      0.000557      0.237105
# std          0.920198      0.008314      0.009652      0.391578
# ...

# %%
stock_IPO_list[['sym_day0_OTC','sym_1day_ret','sym_5day_ret','sym_22day_ret','sym_91day_ret', 'sym_252day_ret',
'iwv_day0_OTC','iwv_1day_ret', 'iwv_5day_ret','iwv_22day_ret','iwv_91day_ret','iwv_252day_ret']] .describe ()
# Out:
#        sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  sym_91day_ret  \
# count   2265.000000   2265.000000   2265.000000    2265.000000    2265.000000
# mean       0.864428      0.041280      0.053452       0.100227       0.216778
# std       40.322031      1.130455      1.326109       1.651445       2.850084
# min       -0.569231     -0.980934     -0.999047      -0.900000      -0.955556
# 25%       -0.027273     -0.016667     -0.026667      -0.057143      -0.142289
# 50%        0.000000      0.000000      0.000000       0.007032       0.014754
# 75%        0.025277      0.020161      0.038650       0.094450       0.212457
# max     1919.000119     53.000000     61.381819      57.981814      89.200000
#
#        sym_252day_ret  iwv_day0_OTC  iwv_1day_ret  iwv_5day_ret  \
# count     2265.000000   2265.000000   2265.000000   2265.000000
# mean         0.256358     -0.000014      0.000674      0.204274
# std          3.527711      0.007545      0.009363      0.407428
# ...

# %%
stock_IPO_list_final
# Out:
#        sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  sym_91day_ret  \
# count   2265.000000   2265.000000   2265.000000    2265.000000    2265.000000
# mean       0.864428      0.041280      0.053452       0.100227       0.216778
# std       40.322031      1.130455      1.326109       1.651445       2.850084
# min       -0.569231     -0.980934     -0.999047      -0.900000      -0.955556
# 25%       -0.027273     -0.016667     -0.026667      -0.057143      -0.142289
# 50%        0.000000      0.000000      0.000000       0.007032       0.014754
# 75%        0.025277      0.020161      0.038650       0.094450       0.212457
# max     1919.000119     53.000000     61.381819      57.981814      89.200000
#
#        sym_252day_ret  iwv_day0_OTC  iwv_1day_ret  iwv_5day_ret  \
# count     2265.000000   2265.000000   2265.000000   2265.000000
# mean         0.256358     -0.000014      0.000674      0.204274
# std          3.527711      0.007545      0.009363      0.407428
# ...

# %%
stock_IPO_list_corr=stock_IPO_list[['sym_day0_OTC','sym_1day_ret','sym_5day_ret','sym_22day_ret','sym_91day_ret', 'sym_252day_ret',
'iwv_day0_OTC','iwv_1day_ret', 'iwv_5day_ret','iwv_22day_ret','iwv_91day_ret','iwv_252day_ret']] .corr ()
stock_IPO_list_corr
# calling coorelation to stock_IPO_list_corr
# Out:
#                 sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  \
# sym_day0_OTC        1.000000     -0.000733     -0.000862      -0.001084
# sym_1day_ret       -0.000733      1.000000      0.976581       0.744140
# sym_5day_ret       -0.000862      0.976581      1.000000       0.777658
# sym_22day_ret      -0.001084      0.744140      0.777658       1.000000
# sym_91day_ret      -0.001626      0.492886      0.512759       0.810196
# sym_252day_ret     -0.001135      0.008620      0.043144       0.525173
# iwv_day0_OTC       -0.016428      0.008497      0.008095       0.012645
# iwv_1day_ret       -0.006579      0.020399      0.016964       0.007441
# iwv_5day_ret       -0.009353     -0.019103     -0.013176       0.010382
# iwv_22day_ret      -0.018895      0.020720      0.027526       0.043097
# iwv_91day_ret       0.015408      0.022544      0.020644       0.001794
# iwv_252day_ret      0.019782     -0.009591     -0.015608      -0.021348
#
# ...

# %%
stock_IPO_list_corr
# Out:
#                 sym_day0_OTC  sym_1day_ret  sym_5day_ret  sym_22day_ret  \
# sym_day0_OTC        1.000000     -0.000733     -0.000862      -0.001084
# sym_1day_ret       -0.000733      1.000000      0.976581       0.744140
# sym_5day_ret       -0.000862      0.976581      1.000000       0.777658
# sym_22day_ret      -0.001084      0.744140      0.777658       1.000000
# sym_91day_ret      -0.001626      0.492886      0.512759       0.810196
# sym_252day_ret     -0.001135      0.008620      0.043144       0.525173
# iwv_day0_OTC       -0.016428      0.008497      0.008095       0.012645
# iwv_1day_ret       -0.006579      0.020399      0.016964       0.007441
# iwv_5day_ret       -0.009353     -0.019103     -0.013176       0.010382
# iwv_22day_ret      -0.018895      0.020720      0.027526       0.043097
# iwv_91day_ret       0.015408      0.022544      0.020644       0.001794
# iwv_252day_ret      0.019782     -0.009591     -0.015608      -0.021348
#
# ...

# %%
df_ETF_ipos.corr()
# Out:
# /var/folders/nd/mvq13b8j3msfgn8hkg4r_p200000gn/T/ipykernel_88693/1499736723.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_ETF_ipos.corr()
#                 Unnamed: 0  sym_day0_OTC  sym_1day_ret  sym_5day_ret  \
# Unnamed: 0        1.000000     -0.020840     -0.003041     -0.006532
# sym_day0_OTC     -0.020840      1.000000     -0.002297      0.005471
# sym_1day_ret     -0.003041     -0.002297      1.000000     -0.160462
# sym_5day_ret     -0.006532      0.005471     -0.160462      1.000000
# sym_22day_ret    -0.006014      0.007691     -0.156852      0.997466
# sym_91day_ret    -0.000552      0.015186     -0.172841      0.986132
# sym_252day_ret    0.001057     -0.000295     -0.146932      0.977572
# iwv_day0_OTC      0.016795      0.186849      0.019617     -0.002693
# ...

# %%
df= df_ETF_ipos.describe()
mean_252 = pd.DataFrame( df[['sym_252day_ret', 'iwv_252day_ret']].loc['mean'] )
mean_252
# Out:
#                     mean
# sym_252day_ret  0.086627
# iwv_252day_ret  0.115910

# %%
mean_252['mean'].plot(kind='bar')
# measuring mean of 1 year return bar graph sym, and iwv
# Out:
# <AxesSubplot: >
